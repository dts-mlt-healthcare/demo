# %% [markdown]
# <a href="https://colab.research.google.com/github/dts-mlt-healthcare/demo/blob/main/HC1_alma.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import Library

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Load Datasets

# %%
disease = pd.read_csv("dataset.csv")
description = pd.read_csv('symptom_description.csv')
precaution = pd.read_csv('symptom_precaution.csv')
severity = pd.read_csv('symptom_severity.csv')

# %%
disease.head()
# Out:
#             Disease   Symptom_1              Symptom_2              Symptom_3  \
# 0  Fungal infection     itching              skin_rash   nodal_skin_eruptions
# 1  Fungal infection   skin_rash   nodal_skin_eruptions    dischromic _patches
# 2  Fungal infection     itching   nodal_skin_eruptions    dischromic _patches
# 3  Fungal infection     itching              skin_rash    dischromic _patches
# 4  Fungal infection     itching              skin_rash   nodal_skin_eruptions
#
#               Symptom_4 Symptom_5 Symptom_6 Symptom_7 Symptom_8 Symptom_9  \
# 0   dischromic _patches       NaN       NaN       NaN       NaN       NaN
# 1                   NaN       NaN       NaN       NaN       NaN       NaN
# 2                   NaN       NaN       NaN       NaN       NaN       NaN
# 3                   NaN       NaN       NaN       NaN       NaN       NaN
# 4                   NaN       NaN       NaN       NaN       NaN       NaN
#
# ...

# %%
disease.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4920 entries, 0 to 4919
# Data columns (total 18 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Disease     4920 non-null   object
#  1   Symptom_1   4920 non-null   object
#  2   Symptom_2   4920 non-null   object
#  3   Symptom_3   4920 non-null   object
#  4   Symptom_4   4572 non-null   object
#  5   Symptom_5   3714 non-null   object
#  6   Symptom_6   2934 non-null   object
#  7   Symptom_7   2268 non-null   object
#  8   Symptom_8   1944 non-null   object
#  9   Symptom_9   1692 non-null   object
#  10  Symptom_10  1512 non-null   object
#  11  Symptom_11  1194 non-null   object
#  12  Symptom_12  744 non-null    object
#  13  Symptom_13  504 non-null    object
#  14  Symptom_14  306 non-null    object
#  15  Symptom_15  240 non-null    object
#  16  Symptom_16  192 non-null    object
#  17  Symptom_17  72 non-null     object
# dtypes: object(18)
# memory usage: 692.0+ KB

# %% [markdown]
# DataFrame "disease" tidak mengandung data jenis numerik.

# %%
description.head()
# Out:
#           Disease                                        Description
# 0   Drug Reaction  An adverse drug reaction (ADR) is an injury ca...
# 1         Malaria  An infectious disease caused by protozoan para...
# 2         Allergy  An allergy is an immune system response to a f...
# 3  Hypothyroidism  Hypothyroidism, also called underactive thyroi...
# 4       Psoriasis  Psoriasis is a common skin disorder that forms...

# %%
description.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41 entries, 0 to 40
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Disease      41 non-null     object
#  1   Description  41 non-null     object
# dtypes: object(2)
# memory usage: 784.0+ bytes

# %% [markdown]
# DataFrame "description" tidak mengandung data jenis numerik.

# %%
precaution.head()
# Out:
#           Disease                      Precaution_1  \
# 0   Drug Reaction                   stop irritation
# 1         Malaria          Consult nearest hospital
# 2         Allergy                    apply calamine
# 3  Hypothyroidism                     reduce stress
# 4       Psoriasis  wash hands with warm soapy water
#
#                    Precaution_2        Precaution_3  \
# 0      consult nearest hospital    stop taking drug
# 1               avoid oily food  avoid non veg food
# 2       cover area with bandage                 NaN
# 3                      exercise         eat healthy
# 4  stop bleeding using pressure      consult doctor
#
#                   Precaution_4
# 0                    follow up
# 1           keep mosquitos out
# 2  use ice to compress itching
# 3             get proper sleep
# 4                   salt baths

# %%
precaution.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41 entries, 0 to 40
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Disease       41 non-null     object
#  1   Precaution_1  41 non-null     object
#  2   Precaution_2  41 non-null     object
#  3   Precaution_3  40 non-null     object
#  4   Precaution_4  40 non-null     object
# dtypes: object(5)
# memory usage: 1.7+ KB

# %% [markdown]
# DataFrame "precaution" tidak mengandung data jenis numerik.

# %%
severity.head()
# Out:
#                 Symptom  weight
# 0               itching       1
# 1             skin_rash       3
# 2  nodal_skin_eruptions       4
# 3   continuous_sneezing       4
# 4             shivering       5

# %%
severity.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133 entries, 0 to 132
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Symptom  133 non-null    object
#  1   weight   133 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 2.2+ KB

# %% [markdown]
# DataFrame "severity" mengandung data jenis numerik untuk fitur "weight".

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## EDA DataFrame "precaution"

# %%
precaution.describe()
# Out:
#               Disease              Precaution_1 Precaution_2    Precaution_3  \
# count              41                        41           41              40
# unique             41                        32           34              30
# top     Drug Reaction  Consult nearest hospital     exercise  consult doctor
# freq                1                         3            3               6
#
#        Precaution_4
# count            40
# unique           24
# top       follow up
# freq              6

# %%
precautions = precaution.drop(columns='Disease')
precautions = pd.melt(precautions)
precautions
# Out:
#          variable                             value
# 0    Precaution_1                   stop irritation
# 1    Precaution_1          Consult nearest hospital
# 2    Precaution_1                    apply calamine
# 3    Precaution_1                     reduce stress
# 4    Precaution_1  wash hands with warm soapy water
# ..            ...                               ...
# 159  Precaution_4                               NaN
# 160  Precaution_4                         follow up
# 161  Precaution_4                           massage
# 162  Precaution_4             ease back into eating
# 163  Precaution_4                              rest
#
# [164 rows x 2 columns]

# %%
_ = dict(precautions['value'].value_counts())
_
# Out:
# {'Consult nearest hospital': 3,
#  'acetaminophen': 1,
#  'anti itch medicine': 1,
#  'antiboitic therapy': 1,
#  'apply calamine': 1,
#  'avoid abrupt head movment': 1,
#  'avoid cold food': 1,
#  'avoid fatty spicy food': 6,
#  'avoid lying down after eating': 1,
#  'avoid non veg food': 1,
#  'avoid oily food': 1,
#  'avoid open cuts': 1,
#  'avoid public places': 1,
#  'avoid sudden change in body': 1,
#  'avoid too many products': 1,
#  'bath twice': 2,
#  'call ambulance': 1,
#  'check in pulse': 1,
#  'chew or swallow asprin': 1,
#  'cold baths': 1,
#  'consult doctor': 15,
#  'consult nearest hospital': 3,
#  'consume alovera juice': 1,
#  'consume milk thistle': 1,
#  'consume neem leaves': 1,
#  'consume probiotic food': 1,
#  'consume witch hazel': 1,
#  'cover area with bandage': 1,
#  'cover mouth': 1,
#  'dont stand still for long': 1,
#  'drink cranberry juice': 1,
#  'drink papaya leaf juice': 1,
#  'drink plenty of water': 3,
#  'drink sugary drinks': 1,
# ...

# %% [markdown]
# ## Untuk ditindaklanjuti
# ### Apakah bisa disatukan?
# 1. 'Consult nearest hospital' == 'consult nearest hospital'
# 2. 'antiboitic therapy' == 'use antibiotics'
# 3. 'drink vitamin c rich drinks' == 'increase vitamin c intake'
# 4. 'drink plenty of water' == 'keep hydrated'
# 5. 'keep mosquitos away' == 'keep mosquitos out'
# 6. 'meditation' == 'reduce stress' == 'relax'
# 7. 'get proper sleep' == 'rest'
# 8. 'use heating pad or cold pack' == 'use hot and cold therapy'
# 9. 'take vaccine' == 'vaccination'
#
# ### Apakah perlu diperbaiki atau diganti?
# 1. 'antiboitic therapy'
# 2. 'avoid abrupt head movment'
# 3. 'eat high calorie vegitables'
# 4. 'use poloroid glasses in sun'

# %% [markdown]
# ## EDA DataFrame "severity"

# %%
severity.Symptom.isnull().value_counts()
# Out:
# False    133
# Name: Symptom, dtype: int64

# %%
severity.weight.isnull().value_counts()
# Out:
# False    133
# Name: weight, dtype: int64

# %%
_ = dict(severity.Symptom.value_counts())
_
# Out:
# {'abdominal_pain': 1,
#  'abnormal_menstruation': 1,
#  'acidity': 1,
#  'acute_liver_failure': 1,
#  'altered_sensorium': 1,
#  'anxiety': 1,
#  'back_pain': 1,
#  'belly_pain': 1,
#  'blackheads': 1,
#  'bladder_discomfort': 1,
#  'blister': 1,
#  'blood_in_sputum': 1,
#  'bloody_stool': 1,
#  'blurred_and_distorted_vision': 1,
#  'breathlessness': 1,
#  'brittle_nails': 1,
#  'bruising': 1,
#  'burning_micturition': 1,
#  'chest_pain': 1,
#  'chills': 1,
#  'cold_hands_and_feets': 1,
#  'coma': 1,
#  'congestion': 1,
#  'constipation': 1,
#  'continuous_feel_of_urine': 1,
#  'continuous_sneezing': 1,
#  'cough': 1,
#  'cramps': 1,
#  'dark_urine': 1,
#  'dehydration': 1,
#  'depression': 1,
#  'diarrhoea': 1,
#  'dischromic_patches': 1,
#  'distention_of_abdomen': 1,
#  'dizziness': 1,
#  'drying_and_tingling_lips': 1,
#  'enlarged_thyroid': 1,
#  'excessive_hunger': 1,
#  'extra_marital_contacts': 1,
#  'family_history': 1,
#  'fast_heart_rate': 1,
#  'fatigue': 1,
# ...
